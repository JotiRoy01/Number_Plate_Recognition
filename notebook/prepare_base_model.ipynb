# %%
from ANPR.constants import *
from ANPR.entity.config_entity import *
from ANPR.config.configuration import Configuration

from pathlib import Path

# %%
CONFIG_FILE_PATH = 'd:\\Develops\\ML_PROJECT\\Number_Plate_Recognition\\config\\config.yaml'

# %%
config_info = Configuration(CONFIG_FILE_PATH)

# %%
import tensorflow as tf

# %%
config_info.get_prepare_base_model_config().base_model_path
# Out:
# 'd:\\Develops\\ML_PROJECT\\Number_Plate_Recognition\\notebook\\src\\ANPR\\artifacts\\PrepareBaseModel\\base_model.h5'

# %%
tf.keras.Model
# Out:
# keras.src.models.model.Model

# %%
model = tf.keras.applications.InceptionResNetV2(
    input_shape = IMAGE_SIZE,
    weights = WEIGHTS,
    include_top = INCLUDE_TOP
)

# %%
base_model_path = Path(config_info.get_prepare_base_model_config().base_model_path)

# %%
base_model_path
# Out:
# WindowsPath('d:/Develops/ML_PROJECT/Number_Plate_Recognition/notebook/src/ANPR/artifacts/PrepareBaseModel/base_model.h5')

# %%
model.save(base_model_path)

# %%
model.summary()

# %%
model.output
# Out:
# <KerasTensor shape=(None, 5, 5, 1536), dtype=float32, sparse=False, name=keras_tensor_779>

# %%
model_output = model.output
model_output = tf.keras.layers.Flatten()(model_output)
model_output = tf.keras.layers.Dense(500, activation='relu')(model_output)
model_output = tf.keras.layers.Dense(250, activation='relu')(model_output)
model_output = tf.keras.layers.Dense(4, activation='sigmoid')(model_output)
def new_func(model_output):
    final_model = tf.keras.models.Model(inputs=model.input, outputs=model_output)
    return final_model

final_model = new_func(model_output)

final_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
    metrics=['accuracy'],
    loss='mse'
)
final_model.save(config_info.get_prepare_base_model_config().updated_model_path)

# %%
model.input
# Out:
# <KerasTensor shape=(None, 224, 224, 3), dtype=float32, sparse=False, name=keras_tensor>

# %%
for layer in final_model.layers:
    print(f"Layer: {layer.name}, Input: {layer.input}, Output: {layer.output}")
# Out:
# Layer: input_layer, Input: [], Output: <KerasTensor shape=(None, 224, 224, 3), dtype=float32, sparse=False, name=keras_tensor>
# Layer: conv2d, Input: <KerasTensor shape=(None, 224, 224, 3), dtype=float32, sparse=False, name=keras_tensor>, Output: <KerasTensor shape=(None, 111, 111, 32), dtype=float32, sparse=False, name=keras_tensor_1>
# Layer: batch_normalization, Input: <KerasTensor shape=(None, 111, 111, 32), dtype=float32, sparse=False, name=keras_tensor_1>, Output: <KerasTensor shape=(None, 111, 111, 32), dtype=float32, sparse=False, name=keras_tensor_2>
# Layer: activation, Input: <KerasTensor shape=(None, 111, 111, 32), dtype=float32, sparse=False, name=keras_tensor_2>, Output: <KerasTensor shape=(None, 111, 111, 32), dtype=float32, sparse=False, name=keras_tensor_3>
# ...

# %%
tf.keras.

# %%
<KerasTensor shape=(None, 224, 224, 3), dtype=float32, sparse=False, name=keras_tensor>
